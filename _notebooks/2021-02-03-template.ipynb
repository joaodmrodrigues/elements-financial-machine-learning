# %% [markdown]
# # Title
# > Small summary
#
# - toc: true
# - branch: master
# - badges: true
# - comments: true
# - categories: [cathegory 1, other cathegory]
# - image: images/post_image_generic.jpg
# - hide: false
# - search_exclude: false
# - author: Joao Rodrigues

# %% [markdown]
# ## Subtitle

# %% [markdown]
# ### Subsubtitle

# %% [markdown]
# And some text here

# %%
#collapse-hide
var1 = 5

# %%
#hide_input
print("This code cell was not shown, only the output")
# Out:
# This code cell was not shown, only the output

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(1, 100, 100)
y = np.random.randn(100)

plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Callout boxes

# %% [markdown]
# > Warning: This is a warning

# %% [markdown]
# > Important: This is important

# %% [markdown]
# > Tip: This is a tip

# %% [markdown]
# > Note: This is a note

# %% [markdown]
# > Note: This is a note with a [link](https://en.wikipedia.org/wiki/Main_Page)
